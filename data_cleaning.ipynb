# %% [markdown]
# ## ABOUT THE PROYECT

# %% [markdown]
# ## DATA EXTRACTION

# %%
import pandas as pd
import numpy as np
# %pip install sweetviz
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\fer-h\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
df2017=pd.read_csv('data/Produccion_Pesquera_2017.csv',encoding='latin-1')
df2018=pd.read_csv('data/Produccion_Pesquera_2018.csv',encoding='latin-1')
df2019=pd.read_csv('data/Produccion_Pesquera_2019.csv',encoding='latin-1')
df2020=pd.read_csv('data/Produccion_Pesquera_2020.csv',encoding='latin-1')
df=pd.concat([df2017, df2018,df2019,df2020],axis=0).reset_index()
display(df.head(20))
# Out:
# C:\Users\fer-h\AppData\Local\Temp\ipykernel_48064\4065024089.py:1: DtypeWarning: Columns (1,2,3,4,5,6,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2017=pd.read_csv('data/Produccion_Pesquera_2017.csv',encoding='latin-1')
# C:\Users\fer-h\AppData\Local\Temp\ipykernel_48064\4065024089.py:2: DtypeWarning: Columns (1,2,3,4,5,6,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2018=pd.read_csv('data/Produccion_Pesquera_2018.csv',encoding='latin-1')
# C:\Users\fer-h\AppData\Local\Temp\ipykernel_48064\4065024089.py:3: DtypeWarning: Columns (1,2,3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2019=pd.read_csv('data/Produccion_Pesquera_2019.csv',encoding='latin-1')
#     index  EJERCICIO FISCAL   ENTIDAD FEDERATIVA         NOMBRE OFICINA  \
# 0       0            2017.0      BAJA CALIFORNIA             SAN FELIPE
# ...

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# there is a few things we can change or delete; for example the years are registered as intergers and the 2 last columns are not relevant for our analysis.

# %%
#rename columns and data frame and deletion of the 2 last columns
df_fishing_2017_2020 = df.rename(columns={'ENTIDAD FEDERATIVA':'ESTADO','EJERCICIO FISCAL':'FECHA','NOMBRE OFICINA':'OFICINA',"NOMBRE PRINCIPAL":'FAMILIA',"NOMBRE COMUN":'ESPECIE'}).drop(columns=['CLAVE DE ENTIDAD','CLAVE DE OFICINA'])
df_fishing_2017_2020.head(10)
# Out:
#     FECHA               ESTADO         OFICINA MES DE CORTE   ORIGEN  ESPECIE  \
# 0  2017.0      BAJA CALIFORNIA      SAN FELIPE        JULIO  CAPTURA  ABADEJO
# 1  2017.0      BAJA CALIFORNIA      SAN FELIPE        JULIO  CAPTURA  ABADEJO
# 2  2017.0  BAJA CALIFORNIA SUR  BAHIA ASUNCION       AGOSTO  CAPTURA  ABADEJO
# 3  2017.0  BAJA CALIFORNIA SUR   SANTA ROSALIA    NOVIEMBRE  CAPTURA  ABADEJO
# 4  2017.0               COLIMA         TECOMAN      FEBRERO  CAPTURA  ABADEJO
# 5  2017.0             CAMPECHE          ATASTA    NOVIEMBRE  CAPTURA  ABADEJO
# 6  2017.0             CAMPECHE        CAMPECHE        ENERO  CAPTURA  ABADEJO
# 7  2017.0             CAMPECHE        CAMPECHE        ABRIL  CAPTURA  ABADEJO
# 8  2017.0             CAMPECHE        CAMPECHE         MAYO  CAPTURA  ABADEJO
# 9  2017.0             CAMPECHE       CHAMPOTON         MAYO  CAPTURA  ABADEJO
#
#   PESO DESEMBARCADO KILOGRAMOS PESO VIVO KILOGRAMOS  VALOR PESOS FAMILIA
# ...

# %%
df_fishing_2017_2020['FECHA']=df_fishing_2017_2020['FECHA'].apply(str)

# %%
df_fishing_2017_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312752 entries, 0 to 63235
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   FECHA                         312752 non-null  object
#  1   ESTADO                        251440 non-null  object
#  2   OFICINA                       251440 non-null  object
#  3   MES DE CORTE                  251440 non-null  object
#  4   ORIGEN                        251440 non-null  object
#  5   ESPECIE                       251440 non-null  object
#  6   PESO DESEMBARCADO KILOGRAMOS  251440 non-null  object
#  7   PESO VIVO KILOGRAMOS          251440 non-null  object
#  8   VALOR PESOS                   251440 non-null  object
#  9   FAMILIA                       251440 non-null  object
# dtypes: object(10)
# memory usage: 26.2+ MB

# %%
df_fishing_2017_2020.describe(include='all')
# Out:
#          FECHA               ESTADO   OFICINA MES DE CORTE   ORIGEN  \
# count   312752               251440    251440       251440   251440
# unique       5                   31       157           12        2
# top     2017.0  BAJA CALIFORNIA SUR  ENSENADA        MARZO  CAPTURA
# freq     64386                31614      5571        22339   230078
#
#            ESPECIE PESO DESEMBARCADO KILOGRAMOS PESO VIVO KILOGRAMOS  \
# count       251440                       251440               251440
# unique         675                        67919                77851
# top     TILAPIA SE                          100                    0
# freq         10935                         1438                 1250
#
#        VALOR PESOS FAMILIA
# count       251440  251440
# unique      170970      57
# top          6,000   OTRAS
# freq           247   48999

# %%
df_fishing_2017_2020=df_fishing_2017_2020.set_index(['FECHA','ORIGEN','FAMILIA','ESPECIE'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\fer-h\Documents\GitHub\Mexican_Fishing\data_cleaning.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fer-h/Documents/GitHub/Mexican_Fishing/data_cleaning.ipynb#ch0000003?line=0'>1</a> df_fishing_2017_2020=df_fishing_2017_2020.set_index(['FECHA','ORIGEN','FAMILIA','ESPECIE'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/fer-h/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
# ...
